# %% [markdown]
# <a href="https://colab.research.google.com/github/Vdivyajaswanthi123/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progressive skills needed for AI development:
#
# *   **Foundation (Layers 1 & 2):** Starts with **Data Fundamentals** (collection, cleaning, management) and **Mathematical/Statistical Principles** (linear algebra, calculus, probability) as the base for understanding AI.
# *   **Core AI (Layer 3):** Focuses on **Machine Learning Algorithms**, encompassing various models and techniques (e.g., supervised, unsupervised, deep learning architectures).
# *   **Implementation (Layer 4):** Involves **Software Engineering & Deployment**, covering coding, MLOps, cloud platforms, and integrating models into real-world applications.
# *   **Impact & Strategy (Layer 5):** The peak is **Domain Expertise & Ethics**, ensuring AI solutions address real-world problems effectively, responsibly, and ethically within specific industries.
