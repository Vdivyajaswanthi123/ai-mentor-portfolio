# %% [markdown]
# <a href="https://colab.research.google.com/github/Vdivyajaswanthi123/ai-mentor-portfolio/blob/main/Day10_MultiAgent_LAB_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"
# !pip install -q --upgrade crewai litellm google-generativeai google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 920.0 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 55.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 1.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 973.9 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 1.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 976.4/976.4 kB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.5/111.5 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 822.5/822.5 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.2/178.2 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.7/360.7 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.8/334.8 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.1/731.1 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.3/122.3 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 5.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.53.0 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-api>=1.35.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# google-adk 1.29.0 requires google-genai<2.0.0,>=1.64.0, but you have google-genai 2.7.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-exporter-otlp-proto-http>=1.36.0, but you have opentelemetry-exporter-otlp-proto-http 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# wandb 0.27.0 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# bigframes 2.40.0 requires rich<14,>=12.4.4, but you have rich 14.3.4 which is incompatible.

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# 05:12:20 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 05:12:20 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
llm = "gemini/gemini-2.5-flash"

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 2cd1807e-43c2-4c08-9f69-d6c87888b8f0                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: ade01faf-de1c-4be8-8e7e-6c9dbb72d32b                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here is a placement brief for TCS Digital preparation:                                                         │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │                                                                                                                 │
# │  *   **TCS National Qualifier Test (NQT):** The primary gateway, typically involves sections on Cognitive       │
# │  Skills (Numerical, Verbal, Reasoning), Programming Logic, and Advanced Coding.                                 │
# │  *   **Technical Interview:** Focuses on Data Structures & Algorithms (DSA), core CS fundamentals (OS, DBMS,    │
# │  OOPS), projects, and chosen programming language.                                                              │
# │  *   **Managerial Interview:** Evaluates problem-solving approach, project experience, leadership potential,    │
# │  and technical depth.                                                                                           │
# │  *   **HR Interview:** Assesses communication skills, career aspirations, cultural fit, and verifies resume     │
# │  details.                                                                                                       │
# │  *   **Advanced Coding Round (for some roles/high scorers):** A more challenging coding assessment to identify  │
# │  candidates for premium roles like Digital.                                                                     │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │                                                                                                                 │
# │  *   **Programming Languages:** Strong proficiency in Java, Python, or C++ is essential.                        │
# │  *   **Data Structures & Algorithms (DSA):** Fundamental understanding and problem-solving ability using        │
# │  various data structures and algorithms.                                                                        │
# │  *   **Web Technologies:** Basic understanding of HTML, CSS, JavaScript; awareness of frameworks like           │
# │  React/Angular/Node.js is beneficial.                                                                           │
# │  *   **Databases:** Knowledge of SQL (e.g., MySQL, PostgreSQL) and database management concepts.                │
# │  *   **Core CS Concepts:** Operating Systems, Object-Oriented Programming (OOPs), Database Management Systems   │
# │  (DBMS), and Computer Networks.                                                                                 │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │                                                                                                                 │
# │  *   **Academic Qualification:** B.Tech/BE in Computer Science, Information Technology, Electronics &           │
# │  Communication, Electrical & Electronics, or related disciplines.                                               │
# │  *   **Academic Percentage:** A consistent academic record, typically 60% or 6.0 CGPA throughout 10th, 12th,    │
# │  and graduation.                                                                                                │
# │  *   **Backlogs:** No active backlogs at the time of appearing for the test or joining.                         │
# │  *   **Educational Gap:** Usually a maximum permissible gap of 1-2 years in education, with valid reasons.      │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │                                                                                                                 │
# │  *   **Increased Focus on Digital Skills:** Strong demand for expertise in Cloud Computing (AWS, Azure, GCP),   │
# │  AI/ML, Cybersecurity, and IoT.                                                                                 │
# │  *   **Problem-Solving Emphasis:** The hiring process prioritizes candidates with strong analytical and         │
# │  problem-solving skills, reflected in tougher coding challenges.                                                │
# │  *   **NQT as a Primary Channel:** TCS NQT remains the main entry point, with scores often determining          │
# │  eligibility for Ninja (base package) vs. Digital (premium package) roles.                                      │
# │  *   **Full-Stack & Cross-Functional Talent:** Preference for candidates with versatile skills, capable of      │
# │  working across different layers of software development.                                                       │
# │  *   **Automation in Screening:** Leveraging AI-based tools for initial resume screening and online             │
# │  assessments for efficiency.                                                                                    │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │                                                                                                                 │
# │  *   **Master DSA:** Dedicate significant time to practicing Data Structures and Algorithms on platforms like   │
# │  LeetCode, HackerRank, and GeeksforGeeks.                                                                       │
# │  *   **Strengthen Core CS Fundamentals:** Thoroughly revise Operating Systems, DBMS, OOPS concepts, and         │
# │  Computer Networks.                                                                                             │
# │  *   **Coding Proficiency:** Become highly proficient in at least one preferred programming language (Java,     │
# │  Python, or C++).                                                                                               │
# │  *   **Build Projects:** Develop 1-2 significant personal or academic projects to showcase practical            │
# │  application of learned skills.                                                                                 │
# │  *   **Aptitude & Communication:** Regularly practice quantitative aptitude, logical reasoning, and verbal      │
# │  ability. Work on clear and concise communication for interviews.                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: c7a3c0b5-5403-4bfa-94db-f71a5832029d                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Dreaming of a premium tech career? TCS Digital offers a fast track to cutting-edge projects and enhanced       │
# │  opportunities. This brief outlines your path to success – let's get you ready!                                 │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 1. The Hiring Process                                                                                      │
# │                                                                                                                 │
# │  Your journey through TCS Digital recruitment typically involves these key stages:                              │
# │                                                                                                                 │
# │  *   **TCS National Qualifier Test (NQT):** The primary gateway. Covers Cognitive Skills (Numerical, Verbal,    │
# │  Reasoning), Programming Logic, and Advanced Coding. A strong NQT score is crucial for Digital roles.           │
# │  *   **Technical Interview:** A deep dive into your knowledge of Data Structures & Algorithms (DSA), core CS    │
# │  fundamentals (OS, DBMS, OOPS), your projects, and chosen programming language.                                 │
# │  *   **Managerial Interview:** Evaluates your problem-solving approach, project experience, leadership          │
# │  potential, and technical depth.                                                                                │
# │  *   **HR Interview:** Assesses communication skills, career aspirations, cultural fit, and verifies resume     │
# │  details.                                                                                                       │
# │  *   **Advanced Coding Round (for select candidates):** A more challenging coding assessment to identify        │
# │  candidates for premium Digital roles.                                                                          │
# │                                                                                                                 │
# │  ### 2. Essential Technical Stack                                                                               │
# │                                                                                                                 │
# │  Demonstrating proficiency in these areas is key:                                                               │
# │                                                                                                                 │
# │  *   **Programming Languages:** Strong command over Java, Python, or C++.                                       │
# │  *   **Data Structures & Algorithms (DSA):** Fundamental understanding and practical problem-solving.           │
# │  *   **Web Technologies:** Basic understanding of HTML, CSS, JavaScript; awareness of frameworks                │
# │  (React/Angular/Node.js) is beneficial.                                                                         │
# │  *   **Databases:** Knowledge of SQL (e.g., MySQL, PostgreSQL) and core database concepts.                      │
# │  *   **Core CS Concepts:** Operating Systems, Object-Oriented Programming (OOPs), Database Management Systems   │
# │  (DBMS), and Computer Networks.                                                                                 │
# │                                                                                                                 │
# │  ### 3. Eligibility Criteria                                                                                    │
# │                                                                                                                 │
# │  Ensure you meet the basic requirements to be considered:                                                       │
# │                                                                                                                 │
# │  *   **Academic Qualification:** B.Tech/BE in Computer Science, Information Technology, Electronics &           │
# │  Communication, Electrical & Electronics, or related disciplines.                                               │
# │  *   **Academic Percentage:** A consistent academic record, typically 60% or 6.0 CGPA throughout 10th, 12th,    │
# │  and graduation.                                                                                                │
# │  *   **Backlogs:** No active backlogs at the time of appearing for the test or joining.                         │
# │  *   **Educational Gap:** Maximum permissible gap of 1-2 years in education, with valid reasons.                │
# │                                                                                                                 │
# │  ### 4. Recent Hiring Trends                                                                                    │
# │                                                                                                                 │
# │  Stay informed about what TCS Digital is looking for:                                                           │
# │                                                                                                                 │
# │  *   **Increased Focus on Digital Skills:** High demand for expertise in Cloud Computing (AWS, Azure, GCP),     │
# │  AI/ML, Cybersecurity, and IoT.                                                                                 │
# │  *   **Problem-Solving Emphasis:** The hiring process prioritizes candidates with strong analytical and         │
# │  problem-solving skills, reflected in tougher coding challenges.                                                │
# │  *   **NQT as a Primary Channel:** TCS NQT remains the main entry point, with scores often determining          │
# │  eligibility for Ninja (base package) vs. Digital (premium package) roles.                                      │
# │  *   **Full-Stack & Cross-Functional Talent:** Preference for candidates with versatile skills, capable of      │
# │  working across different layers of software development.                                                       │
# │  *   **Automation in Screening:** Leveraging AI-based tools for initial resume screening and online             │
# │  assessments for efficiency.                                                                                    │
# │                                                                                                                 │
# │  ### 5. Effective Preparation Tips                                                                              │
# │                                                                                                                 │
# │  Strategize your preparation for success:                                                                       │
# │                                                                                                                 │
# │  *   **Master DSA:** Dedicate significant time to practicing Data Structures and Algorithms on platforms like   │
# │  LeetCode, HackerRank, and GeeksforGeeks.                                                                       │
# │  *   **Strengthen Core CS Fundamentals:** Thoroughly revise Operating Systems, DBMS, OOPS concepts, and         │
# │  Computer Networks.                                                                                             │
# │  *   **Coding Proficiency:** Become highly proficient in at least one preferred programming language (Java,     │
# │  Python, or C++).                                                                                               │
# │  *   **Build Projects:** Develop 1-2 significant personal or academic projects to showcase practical            │
# │  application of learned skills.                                                                                 │
# │  *   **Aptitude & Communication:** Regularly practice quantitative aptitude, logical reasoning, and verbal      │
# │  ability. Work on clear and concise communication for interviews.                                               │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  Your journey to TCS Digital starts now. Consistent effort, smart preparation, and a sharp focus will unlock    │
# │  unparalleled opportunities. Seize this chance to build a future at the forefront of technology!                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a premium tech career? TCS Digital offers a fast track to cutting-edge projects and enhanced opportunities. This brief outlines your path to success – let's get you ready!
#
# ---
#
# ### 1. The Hiring Process
#
# Your journey through TCS Digital recruitment typically involves these key stages:
#
# *   **TCS National Qualifier Test (NQT):** The primary gateway. Covers Cognitive Skills (Numerical, Verbal, Reasoning), Programming Logic, and Advanced Coding. A strong NQT score is crucial for Digital roles.
# *   **Technical Interview:** A deep dive into your knowledge of Data Structures & Algorithms (DSA), core CS fundamentals (OS, DBMS, OOPS), your projects, and chosen programming language.
# *   **Managerial Interview:** Evaluates your problem-solving approach, project experience, leadership potential, and technical depth.
# *   **HR Interview:** Assesses communication skills, career aspirations, cultural fit, and verifies resume details.
# *   **Advanced Coding Round (for select candidates):** A more challenging coding assessment to identify candidates for premium Digital roles.
#
# ### 2. Essential Technical Stack
#
# Demonstrating proficiency in these areas is key:
#
# *   **Programming Languages:** Strong command over Java, Python, or C++.
# *   **Data Structures & Algorithms (DSA):** Fundamental understanding and practical problem-solving.
# *   **Web Technologies:** Basic understanding of HTML, CSS, JavaScript; awareness of frameworks (React/Angular/Node.js) is beneficial.
# *   **Databases:** Knowledge of SQL (e.g., MySQL, PostgreSQL) and core database concepts.
# *   **Core CS Concepts:** Operating Systems, Object-Oriented Programming (OOPs), Database Management Systems (DBMS), and Computer Networks.
#
# ### 3. Eligibility Criteria
#
# Ensure you meet the basic requirements to be considered:
#
# *   **Academic Qualification:** B.Tech/BE in Computer Science, Information Technology, Electronics & Communication, Electrical & Electronics, or related disciplines.
# *   **Academic Percentage:** A consistent academic record, typically 60% or 6.0 CGPA throughout 10th, 12th, and graduation.
# *   **Backlogs:** No active backlogs at the time of appearing for the test or joining.
# *   **Educational Gap:** Maximum permissible gap of 1-2 years in education, with valid reasons.
#
# ### 4. Recent Hiring Trends
#
# Stay informed about what TCS Digital is looking for:
#
# *   **Increased Focus on Digital Skills:** High demand for expertise in Cloud Computing (AWS, Azure, GCP), AI/ML, Cybersecurity, and IoT.
# *   **Problem-Solving Emphasis:** The hiring process prioritizes candidates with strong analytical and problem-solving skills, reflected in tougher coding challenges.
# *   **NQT as a Primary Channel:** TCS NQT remains the main entry point, with scores often determining eligibility for Ninja (base package) vs. Digital (premium package) roles.
# *   **Full-Stack & Cross-Functional Talent:** Preference for candidates with versatile skills, capable of working across different layers of software development.
# *   **Automation in Screening:** Leveraging AI-based tools for initial resume screening and online assessments for efficiency.
#
# ### 5. Effective Preparation Tips
#
# Strategize your preparation for success:
#
# *   **Master DSA:** Dedicate significant time to practicing Data Structures and Algorithms on platforms like LeetCode, HackerRank, and GeeksforGeeks.
# *   **Strengthen Core CS Fundamentals:** Thoroughly revise Operating Systems, DBMS, OOPS concepts, and Computer Networks.
# *   **Coding Proficiency:** Become highly proficient in at least one preferred programming language (Java, Python, or C++).
# *   **Build Projects:** Develop 1-2 significant personal or academic projects to showcase practical application of learned skills.
# *   **Aptitude & Communication:** Regularly practice quantitative aptitude, logical reasoning, and verbal ability. Work on clear and concise communication for interviews.
#
# ---
#
# Your journey to TCS Digital starts now. Consistent effort, smart preparation, and a sharp focus will unlock unparalleled opportunities. Seize this chance to build a future at the forefront of technology!
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 2cd1807e-43c2-4c08-9f69-d6c87888b8f0                                                                       │
# │  Final Output: # TCS Digital — Placement Prep Brief                                                             │
# │                                                                                                                 │
# │  Dreaming of a premium tech career? TCS Digital offers a fast track to cutting-edge projects and enhanced       │
# │  opportunities. This brief outlines your path to success – let's get you ready!                                 │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 1. The Hiring Process                                                                                      │
# │                                                                                                                 │
# │  Your journey through TCS Digital recruitment typically involves these key stages:                              │
# │                                                                                                                 │
# │  *   **TCS National Qualifier Test (NQT):** The primary gateway. Covers Cognitive Skills (Numerical, Verbal,    │
# │  Reasoning), Programming Logic, and Advanced Coding. A strong NQT score is crucial for Digital roles.           │
# │  *   **Technical Interview:** A deep dive into your knowledge of Data Structures & Algorithms (DSA), core CS    │
# │  fundamentals (OS, DBMS, OOPS), your projects, and chosen programming language.                                 │
# │  *   **Managerial Interview:** Evaluates your problem-solving approach, project experience, leadership          │
# │  potential, and technical depth.                                                                                │
# │  *   **HR Interview:** Assesses communication skills, career aspirations, cultural fit, and verifies resume     │
# │  details.                                                                                                       │
# │  *   **Advanced Coding Round (for select candidates):** A more challenging coding assessment to identify        │
# │  candidates for premium Digital roles.                                                                          │
# │                                                                                                                 │
# │  ### 2. Essential Technical Stack                                                                               │
# │                                                                                                                 │
# │  Demonstrating proficiency in these areas is key:                                                               │
# │                                                                                                                 │
# │  *   **Programming Languages:** Strong command over Java, Python, or C++.                                       │
# │  *   **Data Structures & Algorithms (DSA):** Fundamental understanding and practical problem-solving.           │
# │  *   **Web Technologies:** Basic understanding of HTML, CSS, JavaScript; awareness of frameworks                │
# │  (React/Angular/Node.js) is beneficial.                                                                         │
# │  *   **Databases:** Knowledge of SQL (e.g., MySQL, PostgreSQL) and core database concepts.                      │
# │  *   **Core CS Concepts:** Operating Systems, Object-Oriented Programming (OOPs), Database Management Systems   │
# │  (DBMS), and Computer Networks.                                                                                 │
# │                                                                                                                 │
# │  ### 3. Eligibility Criteria                                                                                    │
# │                                                                                                                 │
# │  Ensure you meet the basic requirements to be considered:                                                       │
# │                                                                                                                 │
# │  *   **Academic Qualification:** B.Tech/BE in Computer Science, Information Technology, Electronics &           │
# │  Communication, Electrical & Electronics, or related disciplines.                                               │
# │  *   **Academic Percentage:** A consistent academic record, typically 60% or 6.0 CGPA throughout 10th, 12th,    │
# │  and graduation.                                                                                                │
# │  *   **Backlogs:** No active backlogs at the time of appearing for the test or joining.                         │
# │  *   **Educational Gap:** Maximum permissible gap of 1-2 years in education, with valid reasons.                │
# │                                                                                                                 │
# │  ### 4. Recent Hiring Trends                                                                                    │
# │                                                                                                                 │
# │  Stay informed about what TCS Digital is looking for:                                                           │
# │                                                                                                                 │
# │  *   **Increased Focus on Digital Skills:** High demand for expertise in Cloud Computing (AWS, Azure, GCP),     │
# │  AI/ML, Cybersecurity, and IoT.                                                                                 │
# │  *   **Problem-Solving Emphasis:** The hiring process prioritizes candidates with strong analytical and         │
# │  problem-solving skills, reflected in tougher coding challenges.                                                │
# │  *   **NQT as a Primary Channel:** TCS NQT remains the main entry point, with scores often determining          │
# │  eligibility for Ninja (base package) vs. Digital (premium package) roles.                                      │
# │  *   **Full-Stack & Cross-Functional Talent:** Preference for candidates with versatile skills, capable of      │
# │  working across different layers of software development.                                                       │
# │  *   **Automation in Screening:** Leveraging AI-based tools for initial resume screening and online             │
# │  assessments for efficiency.                                                                                    │
# │                                                                                                                 │
# │  ### 5. Effective Preparation Tips                                                                              │
# │                                                                                                                 │
# │  Strategize your preparation for success:                                                                       │
# │                                                                                                                 │
# │  *   **Master DSA:** Dedicate significant time to practicing Data Structures and Algorithms on platforms like   │
# │  LeetCode, HackerRank, and GeeksforGeeks.                                                                       │
# │  *   **Strengthen Core CS Fundamentals:** Thoroughly revise Operating Systems, DBMS, OOPS concepts, and         │
# │  Computer Networks.                                                                                             │
# │  *   **Coding Proficiency:** Become highly proficient in at least one preferred programming language (Java,     │
# │  Python, or C++).                                                                                               │
# │  *   **Build Projects:** Develop 1-2 significant personal or academic projects to showcase practical            │
# │  application of learned skills.                                                                                 │
# │  *   **Aptitude & Communication:** Regularly practice quantitative aptitude, logical reasoning, and verbal      │
# │  ability. Work on clear and concise communication for interviews.                                               │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  Your journey to TCS Digital starts now. Consistent effort, smart preparation, and a sharp focus will unlock    │
# │  unparalleled opportunities. Seize this chance to build a future at the forefront of technology!                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 4151

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# Here is a placement brief for TCS Digital preparation:
#
# ### Hiring Process
#
# *   **TCS National Qualifier Test (NQT):** The primary gateway, typically involves sections on Cognitive Skills (Numerical, Verbal, Reasoning), Programming Logic, and Advanced Coding.
# *   **Technical Interview:** Focuses on Data Structures & Algorithms (DSA), core CS fundamentals (OS, DBMS, OOPS), projects, and chosen programming language.
# *   **Managerial Interview:** Evaluates problem-solving approach, project experience, leadership potential, and technical depth.
# *   **HR Interview:** Assesses communication skills, career aspirations, cultural fit, and verifies resume details.
# *   **Advanced Coding Round (for some roles/high scorers):** A more challenging coding assessment to identify candidates for premium role
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a premium tech career? TCS Digital offers a fast track to cutting-edge projects and enhanced opportunities. This brief outlines your path to success – let's get you ready!
#
# ---
#
# ### 1. The Hiring Process
#
# Your journey through TCS Digital recruitment typically involves these key stages:
#
# *   **TCS National Qualifier Test (NQT):** The primary gateway. Covers Cognitive Skills (Numerical, Verbal, Reasoning), Programming Logic, and Advanced Coding. A strong NQT score is crucial for Digital roles.
# *   **Technical Interview:** A deep dive into your knowledge of Data Structures & Algorithms (DSA), core CS fundamentals (OS, DBMS, OOPS), your projects, and chosen programming language.
# *   **Managerial Interview:** Evaluates your problem-solving appro

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")

# %%
with open("tcs_digital_brief.md", "r", encoding="utf-8") as f:
    print(f.read()[:2000])
# Out:
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a premium tech career? TCS Digital offers a fast track to cutting-edge projects and enhanced opportunities. This brief outlines your path to success – let's get you ready!
#
# ---
#
# ### 1. The Hiring Process
#
# Your journey through TCS Digital recruitment typically involves these key stages:
#
# *   **TCS National Qualifier Test (NQT):** The primary gateway. Covers Cognitive Skills (Numerical, Verbal, Reasoning), Programming Logic, and Advanced Coding. A strong NQT score is crucial for Digital roles.
# *   **Technical Interview:** A deep dive into your knowledge of Data Structures & Algorithms (DSA), core CS fundamentals (OS, DBMS, OOPS), your projects, and chosen programming language.
# *   **Managerial Interview:** Evaluates your problem-solving approach, project experience, leadership potential, and technical depth.
# *   **HR Interview:** Assesses communication skills, career aspirations, cultural fit, and verifies resume details.
# *   **Advanced Coding Round (for select candidates):** A more challenging coding assessment to identify candidates for premium Digital roles.
#
# ### 2. Essential Technical Stack
#
# Demonstrating proficiency in these areas is key:
#
# *   **Programming Languages:** Strong command over Java, Python, or C++.
# *   **Data Structures & Algorithms (DSA):** Fundamental understanding and practical problem-solving.
# *   **Web Technologies:** Basic understanding of HTML, CSS, JavaScript; awareness of frameworks (React/Angular/Node.js) is beneficial.
# *   **Databases:** Knowledge of SQL (e.g., MySQL, PostgreSQL) and core database concepts.
# *   **Core CS Concepts:** Operating Systems, Object-Oriented Programming (OOPs), Database Management Systems (DBMS), and Computer Networks.
#
# ### 3. Eligibility Criteria
#
# Ensure you meet the basic requirements to be considered:
#
# *   **Academic Qualification:** B.Tech/BE in Computer Science, Information Technology, Electronics & Communication, Electrical & Electronics, or related disciplin
